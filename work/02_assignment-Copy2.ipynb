# %% [markdown]
# # Assignment: Working with Data

# %% [markdown]
# >Using the data below, answer the following questions:
#
# >1) Which entities (top 5) had the largest population density in 2020?
# >2) Which entities have more water area than land area?
# >3) Which entities increased in population the most in the last 10 years?
# >4) What state bird accounts for the largest population as of 2020? Land area?
# >5) How many entities' largest city is their capital city?
# >6) Which city has the largest percent drop from their largest city to their 5th largest? 100*(1st largest - 5th largest)/(1st largest)

# %%
import pandas as pd

# %%
facts = pd.read_csv('../data/state_facts.tsv',delimiter="\t")
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...        City_1 city_1_pop       City_2  \
# ...

# %%
#1 Which entities (top 5) had the largest population density in 2020?

# %%
facts[['Area_land','Pop_2020']].head(5)
# Out:
#    Area_land   Pop_2020
# 0     131171  5024279.0
# 1    1477953   733391.0
# 2        198    49437.0
# 3     294207  7151502.0
# 4     134771  3011524.0

# %%
facts['increase'] = facts['Pop_2020']/facts['Area_land']
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ... city_1_pop       City_2  city_2_pop  \
# ...

# %%
facts.sort_values(by='increase',ascending=False).head(5)
# i accidentally madea decrease column but idk how to delete it
# Out:
#                      State  Area_tot  Area_land  Area_water   Pop_2020  \
# 9    District of Columbia        177        158          19   689545.0
# 32             New Jersey      22591      19047        3544  9288994.0
# 43           Rhode Island       4001       2678        1324  1097379.0
# 42            Puerto Rico      13791       8868        4924  3285874.0
# 23          Massachusetts      27336      20202        7134  7029917.0
#
#     Pop_2010 Rep_seats                               State_bird  \
# 9     601723       1*                              Wood thrush
# 32   8791894        12  Eastern goldfinch (American goldfinch)
# 43   1052567         2                        Rhode Island Red
# 42   3725789       1*                                     None
# 23   6547629         9                  Black-capped chickadee
#
#              State_flower                                 State_motto  ...  \
# 9   American Beauty Rose                            Justitia Omnibus   ...
# ...

# %%
#answer: District of Columbia, New Jersey, Rhode Island, Puerto Rico, Massachusetts

# %%
#2 Which entities have more water area than land area?

# %%
facts['increase'] = facts['Area_water']-facts['Area_land']
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ... city_1_pop       City_2  city_2_pop  \
# ...

# %%
facts.sort_values(by='increase',ascending=False).head(5)#we want the non-negative numbers
# Out:
#                              State  Area_tot  Area_land  Area_water  Pop_2020  \
# 37       Northern Mariana Islands       5117        472        4644      51.0
# 48   United States Virgin Islands       1898        348        1550  106235.0
# 2                  American Samoa       1505        198        1307   49437.0
# 12                           Guam       1478        543         935     168.4
# 9            District of Columbia        177        158          19  689545.0
#
#     Pop_2010 Rep_seats           State_bird                State_flower  \
# 37     53883       1*   Mariana fruit-dove                 Flores mayo
# 48    106405       1*      California gull                Yellow Elder
# 2      55519       1*                  None            Paogo (Ulafala)
# 12    159358       1*   Guam rail (ko'ko')   Bougainvillea spectabilis
# 9     601723       1*          Wood thrush        American Beauty Rose
#
# ...

# %%
#answer: Northern Mariana Islands, United Stats Virgin Islands, American Samoa, Guam

# %%
#3 Which entities increased in population the most in the last 10 years?

# %%
facts['increase'] = facts['Pop_2010']-facts['Pop_2020']
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ... city_1_pop       City_2  city_2_pop  \
# ...

# %%
facts.sort_values(by='increase',ascending=False).head(5)
# Out:
#                          State  Area_tot  Area_land  Area_water    Pop_2020  \
# 42                Puerto Rico      13791       8868        4924   3285874.0
# 12                       Guam       1478        543         935       168.4
# 53              West Virginia      62756      62259         497   1793716.0
# 37   Northern Mariana Islands       5117        472        4644        51.0
# 15                   Illinois     149995     143793        6202  12812508.0
#
#     Pop_2010 Rep_seats           State_bird                State_flower  \
# 42   3725789       1*                 None                Flor de Maga
# 12    159358       1*   Guam rail (ko'ko')   Bougainvillea spectabilis
# 53   1852994         2   Northern cardinal                Rhododendron
# 37     53883       1*   Mariana fruit-dove                 Flores mayo
# 15  12830632        17   Northern cardinal                       Violet
#
#                            State_motto  ... city_1_pop       City_2  \
# ...

# %%
#answer: Puerto Rico, Guam, West Virginia, Northern Mariana Islands, Illinois

# %%
#4 What state bird accounts for the largest population as of 2020? Land area?

# %%
facts.sort_values(by='Pop_2020',ascending=False).head(1)[['State_bird']]
# Out:
#           State_bird
# 5  California quail

# %%
#anwer: California Quail, 403466

# %%
#5 How many entities' largest city is their capital city? - is city 1 the largest city

# %%
facts.columns
# Out:
# Index(['State', 'Area_tot', 'Area_land', 'Area_water', 'Pop_2020', 'Pop_2010',
#        'Rep_seats', 'State_bird', 'State_flower', 'State_motto', 'Motto_trans',
#        'USPS_code', 'GDP_2020', 'GDP_2019', 'Capital', 'Capital_pop', 'City_1',
#        'city_1_pop', 'City_2', 'city_2_pop', 'City_3', 'city_3_pop', 'City_4',
#        'city_4_pop', 'City_5', 'city_5_pop', 'increase'],
#       dtype='object')

# %%
facts[(facts['Capital_pop']>facts['city_1_pop'])
      &(facts['Capital_pop']>facts['city_2_pop'])
      &(facts['Capital_pop']>facts['city_3_pop'])
      &(facts['Capital_pop']>facts['city_4_pop'])
      &(facts['Capital_pop']>facts['city_5_pop'])]
# Out:
#              State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 3         Arizona     295234     294207        1026   7151502.0   6392017
# 6        Colorado     269601     268431        1170   5773714.0   5029196
# 11        Georgia     153910     148959        4951  10711908.0   9687653
# 14          Idaho     216443     214045        2398   1839106.0   1567582
# 16        Indiana      94326      92789        1537   6785528.0   6483802
# 38           Ohio     116098     105829       10269  11799448.0  11536504
# 39       Oklahoma     181037     177660        3377   3959353.0   3751351
# 42    Puerto Rico      13791       8868        4924   3285874.0   3725789
# 43   Rhode Island       4001       2678        1324   1097379.0   1052567
# 55        Wyoming     253335     251470        1864    576851.0    563626
#
#    Rep_seats                  State_bird               State_flower  \
# 3          9                Cactus wren     Saguaro cactus blossom
# ...

# %%
#answer: 10 entities capital cities are their biggest cities assuming City_1 is the capital city

# %%
#6 Which city has the largest percent drop from their largest city to their 5th largest? 
#100*(1st largest - 5th largest)/(1st largest)?

# %%
facts['percent_drop'] = 100*(facts['city_1_pop']-facts['city_5_pop']/facts['city_1_pop'])
facts.sort_values(by='percent_drop',ascending=False).head(1)
# Out:
#          State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 34   New York     141297     122057       19240  20201249.0  19378102
#
#    Rep_seats         State_bird State_flower  State_motto  ...    City_2  \
# 34        26  Eastern bluebird         Rose   Excelsior!   ...  Buffalo
#
#    city_2_pop      City_3  city_3_pop    City_4  city_4_pop     City_5  \
# 34   251298.0  Rochester     206284.0  Yonkers     199663.0  Syracuse
#
#     city_5_pop  increase  percent_drop
# 34    142749.0 -823147.0  8.879928e+08
#
# [1 rows x 28 columns]

# %% [markdown]
# >Using the "state_dates.tsv" data, answer the remaining questions. You will need to merge the two data sets together:
#
# >7) Of the states that joined the United States before 1790, what is the most common state flower?
# >8) Which has the larger population density, the most dense US Territory or the least dense state?
# >9) Make a graph that plots the populations of the largest city in each entity in the order in which they joined the US. Make the bars black
# >10) Make two additional graphs like the one above but one for land area (green bars) and one for water area (blue bars)

# %% [markdown]
# Hint: `pd.read_csv('../data/state_dates.tsv',delimiter="\t")`
#
# Hint: You likely want to convert the Date column to datetime. You might have to correct errors in the data as well.
#
# Hint: `states['Date']<pd.datetime(1790,1,1)`
#
# Hint: `pd.merge(****,****,left_on='USPS_code',right_on='Abbreviation',how='outer')`

# %%
# Sample code to help with the plots

#import matplotlib as plt
#%config InlineBackend.figure_format ='retina' #This makes your plot clearer


#plot = *your df by date*[[*column*,'Abbreviation']].plot(kind='bar',figsize=(10,4))
#plot.set_xticklabels(*your df by date*['Abbreviation']);

# %%
import pandas as pd
states = pd.read_csv('../data/state_dates.tsv',delimiter="\t")
facts = pd.read_csv('../data/state_facts.tsv',delimiter="\t")
states.head(10)
# Out:
#                    Name               Date            Status Abbreviation
# 0              Alabama   December 14, 1819             State          AL
# 1               Alaska     January 3, 1959             State          AK
# 2        American Samoa     April 17, 1900         Territory           AS
# 3              Arizona   February 14, 1912             State          AZ
# 4             Arkansas       June 15, 1836             State          AR
# 5           California   September 9, 1850             State          CA
# 6             Colorado      August 1, 1876             State          CO
# 7          Connecticut     January 9, 1788             State          CT
# 8             Delaware    December 7, 1787             State          DE
# 9  District of Columbia  February 21, 1871  Federal District          DC

# %%
merged = pd.merge(facts,states,left_on='USPS_code',right_on='Abbreviation',how='outer')
merged.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...         City_3 city_3_pop       City_4  \
# ...

# %%
merged['FixedDates'] = pd.to_datetime(states['Date'], errors='raise')

# %%
#7) Of the states that joined the United States before 1790, what is the most common state flower?

# %%
df = merged[merged['FixedDates']<pd.datetime(1790,1,1)]
df['State_flower']
# Out:
# /tmp/ipykernel_15688/1104173136.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df = merged[merged['FixedDates']<pd.datetime(1790,1,1)]
# 7       Mountain laurel
# 8        Peach blossom
# 11        Cherokee rose
# 22    Black-eyed susan
# 23           Mayflower
# 31         Purple lilac
# 32              Violet
# 34                Rose
# 35    Flowering dogwood
# 41      Mountain laurel
# 44     Yellow jessamine
# 51    American dogwood
# Name: State_flower, dtype: object

# %%
#the most common state flower is American dogwood

# %%
df.columns
# Out:
# Index(['State', 'Area_tot', 'Area_land', 'Area_water', 'Pop_2020', 'Pop_2010',
#        'Rep_seats', 'State_bird', 'State_flower', 'State_motto', 'Motto_trans',
#        'USPS_code', 'GDP_2020', 'GDP_2019', 'Capital', 'Capital_pop', 'City_1',
#        'city_1_pop', 'City_2', 'city_2_pop', 'City_3', 'city_3_pop', 'City_4',
#        'city_4_pop', 'City_5', 'city_5_pop', 'Name', 'Date', 'Status',
#        'Abbreviation', 'FixedDates'],
#       dtype='object')

# %%
#8)Which has the larger population density, the most dense US Territory or the least dense state?

# %%
Territory = merged[merged['Status']=="Territory"]
Territory['most_dense_US_terr'] = Territory['Pop_2020']/Territory['Area_land']
Territory.sort_values(by='most_dense_US_terr',ascending=False).head(1)
# Out:
# /tmp/ipykernel_15688/324756181.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Territory['most_dense_US_terr'] = Territory['Pop_2020']/Territory['Area_land']
#             State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 42   Puerto Rico      13791       8868        4924  3285874.0   3725789
#
#    Rep_seats State_bird   State_flower              State_motto  ...  City_4  \
# 42       1*       None   Flor de Maga   Joannes Est Nomen Eius   ...  Ponce
#
#    city_4_pop   City_5  city_5_pop         Name            Date     Status  \
# 42   133191.0  Caguas     124434.0  Puerto Rico  April 11, 1899  Territory
#
#     Abbreviation FixedDates  most_dense_US_terr
# 42            PR 1899-04-11          370.531574
#
# ...

# %%
State = merged[merged['Status']=="State"]
State['least_dense_state'] = State['Pop_2020']/State['Area_land']
State.sort_values(by='least_dense_state',ascending=True).head(1)
# Out:
# /tmp/ipykernel_15688/1477689932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   State['least_dense_state'] = State['Pop_2020']/State['Area_land']
#       State  Area_tot  Area_land  Area_water  Pop_2020  Pop_2010 Rep_seats  \
# 1   Alaska    1723337    1477953      245384  733391.0    710231         1
#
#           State_bird    State_flower           State_motto  ...    City_4  \
# 1  Willow ptarmigan   Forget-me-not   North to the Future   ...  Wasilla
#
#   city_4_pop  City_5  city_5_pop     Name             Date Status  \
# 1    10529.0  Sitka       8647.0  Alaska   January 3, 1959  State
#
#    Abbreviation FixedDates  least_dense_state
# 1           AK  1959-01-03           0.496221
#
# [1 rows x 32 columns]

# %%
#the one with the larger population density is Puerto Rico which is the most dense US Territory

# %%
#9) Make a graph that plots the populations of the largest city in each state in the order in which they joined the US. 
#Make the bars black - largest city is City_1

# %%
import matplotlib as plt
# %config InlineBackend.figure_format ='retina' #This makes your plot clearer

mergedByDate = merged.sort_values(by='FixedDates',ascending=True)
plot = mergedByDate[['city_1_pop','Abbreviation']].plot(kind='bar',figsize=(10,4), color=['black'])
plot.set_xticklabels(mergedByDate['Abbreviation']);

# %%
#10) Make two additional graphs like the one above but one for land area(green bars) and one for water area(blue bars).

# %%
plot = mergedByDate[['Area_land','Abbreviation']].plot(kind='bar',figsize=(10,4), color=['green'])
plot.set_xticklabels(mergedByDate['Abbreviation']);

# %%
plot = mergedByDate[['Area_water','Abbreviation']].plot(kind='bar',figsize=(10,4), color=['blue'])
plot.set_xticklabels(mergedByDate['Abbreviation']);
